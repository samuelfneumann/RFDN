# %%
# Import modules
from lc import LearningCurve
from RFDN import RFDN

# %%
checkpoint = "/home/samuel/Documents/CMPUT511/Project/Checkpoints/RFDN1"
lc = LearningCurve(checkpoint)
lc.plot()
lc.plot("ssim")
lc.plot("loss")
# Out:
# array([12.21126817,  7.44107229,  6.14434933,  5.64235956,  5.58648084,
#         5.31633762,  5.25954857,  5.11521223,  4.99761856,  4.88407636,
#         5.00941294,  4.97389973])
